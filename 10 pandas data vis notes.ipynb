# %%
#calling plots directly from pandas balances ease of use with control over the plot. 
#if you want to make pretty or complicated plots you should just work directly with matplotlib or seaborn
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
import seaborn as sns

# %%
df1 = pd.read_csv('df1',index_col=0)
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2')
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist() #this is basically calling matplot lib under the hood. But you can use seaborn instead if you have loaded it.

# %%
df1['A'].hist(bins = 30)

# %%
df1['A'].plot(kind='hist', bins=30)

# %%
df1['A'].plot.hist() #most common way of plotting things directly in pandas

# %%
df2.plot.area(alpha=0.4)

# %%
df2.plot.bar()

# %%
df1.plot.line(x=df1.index, y='B') #this is exactly what he entered but it wont work for some reason
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-04f4528fc7fc> in <module>
# ----> 1 df1.plot.line(x=df1.index, y='B')
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in line(self, x, y, **kwds)
#    3004             >>> lines = df.plot.line(x='pig', y='horse')
#    3005         """
# -> 3006         return self(kind='line', x=x, y=y, **kwds)
#    3007
#    3008     def bar(self, x=None, y=None, **kwds):
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2940                           fontsize=fontsize, colormap=colormap, table=table,
# ...

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1.index
# Out:
# Index(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04', '2000-01-05',
#        '2000-01-06', '2000-01-07', '2000-01-08', '2000-01-09', '2000-01-10',
#        ...
#        '2002-09-17', '2002-09-18', '2002-09-19', '2002-09-20', '2002-09-21',
#        '2002-09-22', '2002-09-23', '2002-09-24', '2002-09-25', '2002-09-26'],
#       dtype='object', length=1000)

# %%
df1.plot.scatter(x='A', y='B', c='C', cmap = 'coolwarm') #c sets color.  s plots the points according to size. 
#multiply s by a constant to change size range

# %%
df2.plot.box()

# %%
#bivariate data

# %%
#hexariate
df = pd.DataFrame(np.random.randn(1000,2),columns=['a','b'])

# %%
df.head()
# Out:
#           a         b
# 0 -0.359923 -0.015493
# 1 -0.556948  0.740664
# 2 -0.367633  1.109848
# 3  1.108062 -0.981413
# 4 -0.370832 -0.212459

# %%
df.plot.hexbin(x='a', y='b', gridsize=25)

# %%
#KDE plots
df2['a'].plot.kde() #works with .density() too

# %%
df2.plot.kde()
